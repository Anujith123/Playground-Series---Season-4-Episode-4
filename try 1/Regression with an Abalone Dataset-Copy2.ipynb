# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage,fcluster
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.ensemble import BaggingClassifier,GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix, mean_absolute_error, mean_squared_error, r2_score, silhouette_score
from sklearn.model_selection import train_test_split as split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv('train.csv')
df0 = pd.read_csv('test.csv')
d = pd.read_csv('sample_submission.csv')

# %%
df1['Sex'] = df1['Sex'].replace({'M': 0, 'F': 1, 'I': 2})
df0['Sex'] = df0['Sex'].replace({'M': 0, 'F': 1, 'I': 2})
df = df1.drop(['id'], axis=1)
x = df0.drop(['id'], axis=1)

# %%
X = df.drop(['Rings'], axis=1)
y = df.Rings

# %%
# sklearn.linear_model
lr = LinearRegression()
lg = LogisticRegression()

# sklearn.svm
sl = SVC(kernel='linear')      
sp = SVC(kernel='poly', degree=3) 
sr = SVC(kernel='rbf') 
ss = SVC(kernel='sigmoid') 

# sklearn.naive_bayes
nb = GaussianNB()

# sklearn.neighbors
knn = KNeighborsClassifier(n_neighbors=301)

# sklearn.tree
dt = DecisionTreeClassifier(max_depth=3)

# from sklearn.ensemble
rf = RandomForestClassifier(max_depth=3,n_estimators=100)
bg = BaggingClassifier()
bs = GradientBoostingClassifier()

# %%
M = lg

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 
n = n[['id', 'Rings']]

Log = n
a
# Out:
# 34.39

# %%
Log
# Out:
#            id  Rings
# 0       90615      9
# 1       90616      9
# 2       90617      9
# 3       90618      9
# 4       90619      7
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023     10
# 60409  151024     11
# 60410  151025      8
#
# [60411 rows x 2 columns]

# %%
M = sl

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 

linSVM = n[['id', 'Rings']]

a
# Out:
# 35.12

# %%
linSVM
# Out:
#            id  Rings
# 0       90615      9
# 1       90616      9
# 2       90617      9
# 3       90618      9
# 4       90619      7
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023     10
# 60409  151024     11
# 60410  151025      8
#
# [60411 rows x 2 columns]

# %%
M = sp

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 


polSVM = n[['id', 'Rings']]


a
# Out:
# 34.01

# %%
polSVM
# Out:
#            id  Rings
# 0       90615      9
# 1       90616      9
# 2       90617      9
# 3       90618      9
# 4       90619      7
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023      9
# 60409  151024     11
# 60410  151025      7
#
# [60411 rows x 2 columns]

# %%
M = sr

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 

rbfSVM = n[['id', 'Rings']]

a
# Out:
# 34.99

# %%
rbfSVM
# Out:
#            id  Rings
# 0       90615      9
# 1       90616      9
# 2       90617      9
# 3       90618      9
# 4       90619      7
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023      9
# 60409  151024     11
# 60410  151025      9
#
# [60411 rows x 2 columns]

# %%
M = ss

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 

sigSVM = n[['id', 'Rings']]

a
# Out:
# 17.57

# %%
sigSVM
# Out:
#            id  Rings
# 0       90615      9
# 1       90616     10
# 2       90617     13
# 3       90618     13
# 4       90619      7
# ...       ...    ...
# 60406  151021      6
# 60407  151022      8
# 60408  151023      7
# 60409  151024      7
# 60410  151025      6
#
# [60411 rows x 2 columns]

# %%
M = nb

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 

nyb = n[['id', 'Rings']]

a
# Out:
# 30.66

# %%
nyb
# Out:
#            id  Rings
# 0       90615     11
# 1       90616     10
# 2       90617      9
# 3       90618      9
# 4       90619      7
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023      9
# 60409  151024     11
# 60410  151025      7
#
# [60411 rows x 2 columns]

# %%
M = knn

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 

KNN = n[['id', 'Rings']]

a
# Out:
# 36.57

# %%
KNN
# Out:
#            id  Rings
# 0       90615      9
# 1       90616      9
# 2       90617      9
# 3       90618      9
# 4       90619      7
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023      9
# 60409  151024     11
# 60410  151025      9
#
# [60411 rows x 2 columns]

# %%
M = dt

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 

dec = n[['id', 'Rings']]


a
# Out:
# 33.32

# %%
dec
# Out:
#            id  Rings
# 0       90615      9
# 1       90616      9
# 2       90617      9
# 3       90618      9
# 4       90619      8
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023      9
# 60409  151024     11
# 60410  151025      7
#
# [60411 rows x 2 columns]

# %%
M = rf

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 

random = n[['id', 'Rings']]

a
# Out:
# 34.07

# %%
random
# Out:
#            id  Rings
# 0       90615      9
# 1       90616      9
# 2       90617      9
# 3       90618      9
# 4       90619      7
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023      9
# 60409  151024     11
# 60410  151025      8
#
# [60411 rows x 2 columns]

# %%
M = bg

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 

bag = n[['id', 'Rings']]

a
# Out:
# 98.11

# %%
bag
# Out:
#            id  Rings
# 0       90615     10
# 1       90616     10
# 2       90617     11
# 3       90618     10
# 4       90619      8
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023      9
# 60409  151024     11
# 60410  151025      6
#
# [60411 rows x 2 columns]

# %%
M = bs

M.fit(X, y)
p = M.predict(X)
pred = pd.DataFrame({'Rings':p})
a = accuracy_score(y, p)*100
a = round ( a, 2)
k = M.predict(x)
n = pd.DataFrame({'Rings':k})
Id = list(range(90615,151026))
n['id'] = Id 

bst = n[['id', 'Rings']]

a
# Out:
# 39.57

# %%
bst
# Out:
#            id  Rings
# 0       90615      9
# 1       90616      9
# 2       90617      9
# 3       90618      9
# 4       90619      7
# ...       ...    ...
# 60406  151021      6
# 60407  151022      9
# 60408  151023     10
# 60409  151024     11
# 60410  151025      7
#
# [60411 rows x 2 columns]

# %%
predicted_LogisticRegression
predicted_linearSVC   
predicted_polySVC
predicted_rbfSVC
predicted_sigmoidSVC
predicted_naive_bayes
predicted_knn
predicted_DecisionTree
predicted_RandomForest
predicted_Bagging
predicted_Boosting

Log
linSVM
polSVM
rbfSVM
sigSVM
nyb
KNN
dec
random
bag
bst

# %%
Log.to_csv('predicted_LogisticRegression.csv', index=False)
linSVM.to_csv('predicted_linearSVC.csv', index=False)
polSVM.to_csv('predicted_polySVC.csv', index=False)
rbfSVM.to_csv('predicted_rbfSVC.csv', index=False)
sigSVM.to_csv('predicted_sigmoidSVC.csv', index=False)
nyb.to_csv('predicted_naive_bayes.csv', index=False)
KNN.to_csv('predicted_knn.csv', index=False)
dec.to_csv('predicted_DecisionTree.csv', index=False)
random.to_csv('predicted_RandomForest.csv', index=False)
bag.to_csv('predicted_Bagging.csv', index=False)
bst.to_csv('predicted_Boosting.csv', index=False)
